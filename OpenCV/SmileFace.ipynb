# %% [markdown]
# ## Make smile face emoji

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import cv2 # OpenCV-Python
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
img = np.zeros((512, 512), dtype=np.uint8)
plt.imshow(img)

# %%
cv2.rectangle(img, (100,100), (400,400), (0,255,0), 10)
plt.imshow(img)

# %% [markdown]
# ![image.png](attachment:image.png)
